# %% [markdown]
# ###
# ###  TELCO Customer Churn - Exploratory Data Analysis
# ###
# ###
# ###

# %%
# Import required Python Libraries

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
#from ydata_profiling import ProfileReport
from data_profiling import ProfileReport


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
# import source data

src = pd.read_excel("Telco_Customer_Churn.xlsx", sheet_name="Telco_Customer_Churn", header=0)

display(src.head(3))
display("Numbsr of Rows and Columns in Dataframe: ", src.shape)  # (7043, 21)
display(src.info())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  MonthlyCharges TotalCharges Churn
# ...

# %% [markdown]
# """
# Pandas Profiling (now officially known as YData Profiling) is a Python library that automates Exploratory Data Analysis (EDA).
# With just a few lines of code, it generates a detailed interactive report covering :
#
#    missing values,
#    data distributions,
#    correlations, and
#    basic statistics.
# pip install ydata-profiling  now
# pip install fg-data-profiling
# # Before
# import ydata_profiling
# from ydata_profiling import ProfileReport
#
# # After
# import data_profiling
# from data_profiling import ProfileReport
#
# usage:
# from ydata_profiling import ProfileReport
# ### Create the profiling report object
# profile = ProfileReport(df, title="Dataset Profiling Report", explorative=True)
# ### Export to an HTML file
# profile.to_file("output_report.html")
#
# ### Display the report as an interactive iframe
# profile.to_notebook_iframe()
#
# ### Alternatively, display it using widgets
# profile.to_widgets()
# ### Minimal Mode: For very large datasets, generating all detailed statistics can take a while.
# ### You can disable expensive computations by passing minimal=True
# profile = ProfileReport(df, minimal=True)
#
# """

# %%
# Generate Profile report object
profile = ProfileReport(src, title="Telco Customer Churn Data Profiling Report", explorative=True)
#Export to an HTML file
profile.to_file("Telco Customer Churn Source Data Profiling Report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Display the report as an interactive iframe
profile.to_notebook_iframe()
# Out:
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling v4.19.1&quot; name=generator&gt;&lt;meta content=https://github.com/Data-Centric-AI-Community/data-profiling name=url&gt;&lt;meta content=&quot;2026-05-19 18:24:41.320464&quot; name=date&gt;&lt;title&gt;Telco Customer Churn Data Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
df = src.copy()
print(df.shape)
# Out:
# (7043, 21)

# %%
# Replacing blanks with 0 in totalcharges column as its tenure is 0 and 
# its loaded as object so we converted as float

df['TotalCharges']= df['TotalCharges'].replace(" ", "0")
df['TotalCharges'] = df['TotalCharges'].astype('float')

# %%
# total null count in data

print(df.isnull().sum().sum())
# Out:
# 0

# %%
display(df.describe())
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges
# count    7043.000000  7043.000000     7043.000000   7043.000000
# mean        0.162147    32.371149       64.761692   2279.734304
# std         0.368612    24.559481       30.090047   2266.794470
# min         0.000000     0.000000       18.250000      0.000000
# 25%         0.000000     9.000000       35.500000    398.550000
# 50%         0.000000    29.000000       70.350000   1394.550000
# 75%         0.000000    55.000000       89.850000   3786.600000
# max         1.000000    72.000000      118.750000   8684.800000
